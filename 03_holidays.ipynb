# %% [markdown]
# # Imports

# %%
import holidays

import pandas as pd

from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 140)

# %% [markdown]
# # Fixed variables

# %%
PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data"
INPUT_DATA_DIR = DATA_DIR / "input"

output_path = INPUT_DATA_DIR / "03_holidays.csv"

# %% [markdown]
# # Get Data

# %%
spain_holidays = holidays.country_holidays(
    "ES",
    years=[2026],
)

# %%
list(spain_holidays.items())
# Out:
# [(datetime.date(2026, 1, 1), 'Año Nuevo'),
#  (datetime.date(2026, 1, 6), 'Epifanía del Señor'),
#  (datetime.date(2026, 4, 3), 'Viernes Santo'),
#  (datetime.date(2026, 5, 1), 'Fiesta del Trabajo'),
#  (datetime.date(2026, 8, 15), 'Asunción de la Virgen'),
#  (datetime.date(2026, 10, 12), 'Fiesta Nacional de España'),
#  (datetime.date(2026, 12, 8), 'Inmaculada Concepción'),
#  (datetime.date(2026, 12, 25), 'Natividad del Señor')]

# %%
df = (
    pd.DataFrame(
        spain_holidays.items(),
        columns=["date", "holiday_name"]
    )
    .reset_index(drop=True)
)

# %% [markdown]
# # Save Data

# %%
df.to_csv(output_path, index=False)

print(f"Dataset saved to:\n{output_path}")
# Out:
# Dataset saved to:
# c:\Users\jortialo\madrid-electricity-demand-forecasting\data\input\03_holidays.csv
