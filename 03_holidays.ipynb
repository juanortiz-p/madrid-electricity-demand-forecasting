# %% [markdown]
# # Imports

# %%
import holidays

import pandas as pd

from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 140)

# %% [markdown]
# # Fixed variables

# %%
PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data"
INPUT_DATA_DIR = DATA_DIR / "input"

output_path = INPUT_DATA_DIR / "03_holidays.csv"

# %% [markdown]
# # Get Data

# %%
spain_holidays = holidays.country_holidays(
    "ES",
    years=[2025, 2026],
)

# %%
list(spain_holidays.items())
# Out:
# [(datetime.date(2025, 1, 1), "New Year's Day"),
#  (datetime.date(2025, 1, 6), 'Epiphany'),
#  (datetime.date(2025, 4, 18), 'Good Friday'),
#  (datetime.date(2025, 5, 1), 'Labor Day'),
#  (datetime.date(2025, 8, 15), 'Assumption Day'),
#  (datetime.date(2025, 11, 1), "All Saints' Day"),
#  (datetime.date(2025, 12, 6), 'Constitution Day'),
#  (datetime.date(2025, 12, 8), 'Immaculate Conception'),
#  (datetime.date(2025, 12, 25), 'Christmas Day'),
#  (datetime.date(2026, 1, 1), "New Year's Day"),
#  (datetime.date(2026, 1, 6), 'Epiphany'),
#  (datetime.date(2026, 4, 3), 'Good Friday'),
#  (datetime.date(2026, 5, 1), 'Labor Day'),
#  (datetime.date(2026, 8, 15), 'Assumption Day'),
#  (datetime.date(2026, 10, 12), 'National Day'),
#  (datetime.date(2026, 12, 8), 'Immaculate Conception'),
#  (datetime.date(2026, 12, 25), 'Christmas Day')]

# %%
df = (
    pd.DataFrame(
        spain_holidays.items(),
        columns=["date", "holiday_name"]
    )
    .reset_index(drop=True)
)

# %% [markdown]
# # Save Data

# %%
df.to_csv(output_path, index=False)

print(f"Dataset saved to:\n{output_path}")
# Out:
# Dataset saved to:
# C:\Users\jortialo\madrid-electricity-demand-forecasting\data\input\03_holidays.csv
